# %% [markdown]
# <a href="https://colab.research.google.com/github/Japjotongithub/Matplotlib-Python/blob/main/Matplotlib_Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Scatter Plot

# %%
import matplotlib.pyplot as plt

x=[10,20,30,40,44]
y=[1,2,3,4,5]

plt.scatter(x,y,c='g')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2D')
plt.savefig('Test.png')

# %% [markdown]
# # Sine wave

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.arange(0,4*np.pi,0.1)
y=np.sin(x)

plt.plot(x,y)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title("sine wave form")
plt.show()

# %% [markdown]
# # Bar Plot

# %%
import matplotlib.pyplot as plt

x=[2,8,10]
y=[11,12,18]

x2=[3,9,12]
y2=[6,15,7]
plt.bar(x,y,align='center')
plt.bar(x2,y2,color='g',align='center')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Bar Graph')
# Out:
# Text(0.5, 1.0, 'Bar Graph')

# %% [markdown]
# # Histogram

# %%
import matplotlib.pyplot as plt
import numpy as np

a=np.array([22,87,5,43,99,43,3,7,32])
plt.hist(a)
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %% [markdown]
# # Box Plot

# %%
import matplotlib.pyplot as plt
import numpy as np

data=[np.random.normal(0,std,100) for std in range(1,4)]

plt.boxplot(data,vert=True,patch_artist=True)
plt.title('Box Plot')
# Out:
# Text(0.5, 1.0, 'Box Plot')

# %% [markdown]
# # Pie Chart

# %%
import matplotlib.pyplot as plt

labels="Python","C++","Ruby","Java"
sizes=[215,130,245,210]
colors=["gold","yellowgreen","lightcoral","lightskyblue"]
explode=(0.1,0,0,0)
plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct="%1.1f%%",shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7c11dd6b7b50>,
#   <matplotlib.patches.Wedge at 0x7c11de403fd0>,
#   <matplotlib.patches.Wedge at 0x7c11dd4dfd10>,
#   <matplotlib.patches.Wedge at 0x7c11dd485090>],
#  [Text(0.7971028843686665, 0.8970100287795854, 'Python'),
#   Text(-0.6465639380677015, 0.8899185771689371, 'C++'),
#   Text(-0.9490076558502247, -0.5562233985887877, 'Ruby'),
#   Text(0.7466806900156542, -0.8077548806152437, 'Java')],
#  [Text(0.46497668254838875, 0.5232558501214247, '26.9%'),
#   Text(-0.352671238946019, 0.48541013300123836, '16.2%'),
#   Text(-0.517640539554668, -0.3033945810484296, '30.6%'),
#   Text(0.407280376372175, -0.44059357124467835, '26.2%')])
